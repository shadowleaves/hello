# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt
import pandas as pd

# %config InlineBackend.figure_format='png'
pd.Series([0,1,2]).plot()

# %%
# %config InlineBackend.figure_format='retina'
pd.Series([0,1,2]).plot()
